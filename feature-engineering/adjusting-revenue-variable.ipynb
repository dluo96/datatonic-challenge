# %% [markdown]
# # Feature engineering - Adjusting revenue
# To predict whether or not sequels or films inspired by novels are more successful.
#
# ## Tasks this notebook achieves
# - Problem: budget has a large number of missing values
#     - [x] given mean value to rows without budget, this is better than removing as there are a large amount of empty rows
# -  Problem: revenue data is not good enough
#     - [x] I removed zero revenue rows, resulting in 900 rows lost. Not great, but I can’t predict revenue without revenue.
#     - [x] I remove year to only take into account the seasonality of a movie release

# %%
import os
import sys

# %%
sys.path.insert(0, os.path.abspath('/Users/admin/Documents/Jobs/Datatonic/datatonic-challenge/utils/')) #point this to the where util is relatively to your working directory
from util import *

data_dir = get_path_to_data_dir()

# %%
import pandas as pd
import json 
import numpy as np
from datetime import datetime

# %%
movie_details_join = pd.read_pickle(data_dir + 'pre-processed/movie_details_join.pkl')

movie_details_join.set_index('id').head()
# Out:
#           budget  popularity    revenue  runtime  vote_average  vote_count  \
# id
# 64682  105000000   61.196071  351040419    143.0           7.3        3769
# 9543   150000000   62.169881  335154643    116.0           6.2        2317
# 5174   140000000   22.571780  258022233     91.0           6.1         783
# 1735   145000000   60.034162  401128639    112.0           5.2        1387
# 79698   27000000    2.418535          0    109.0           4.8          34
#
#                                                   genres  \
# id
# 64682  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 9543   [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 5174   [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 1735   [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 79698  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                 keywords original_language  \
# id
# 64682  [{"id": 818, "name": "based on novel"}, {"id":...                en
# 9543   [{"id": 1241, "name": "persia"}, {"id": 1965, ...                en
# 5174                [{"id": 1704, "name": "ambassador"}]                en
# 1735                                                  []                en
# 79698                                                 []                en
#
#                               original_title  \
# id
# 64682                       The Great Gatsby
# 9543     Prince of Persia: The Sands of Time
# 5174                             Rush Hour 3
# 1735   The Mummy: Tomb of the Dragon Emperor
# 79698                             The Lovers
#
#                                                 overview  \
# id
# 64682  An adaptation of F. Scott Fitzgerald's Long Is...
# 9543   A rogue prince reluctantly joins forces with a...
# 5174   After an attempted assassination on Ambassador...
# 1735   Archaeologist Rick O'Connell travels to China,...
# 79698  The Lovers is an epic romance time travel adve...
#
#                                     production_companies  \
# id
# 64682  [{"name": "Village Roadshow Pictures", "id": 7...
# 9543   [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 5174             [{"name": "New Line Cinema", "id": 12}]
# 1735   [{"name": "Universal Pictures", "id": 33}, {"n...
# 79698  [{"name": "Corsan", "id": 7299}, {"name": "Bli...
#
#                                     production_countries release_date  \
# id
# 64682  [{"iso_3166_1": "US", "name": "United States o...   2013-05-10
# 9543   [{"iso_3166_1": "US", "name": "United States o...   2010-05-19
# 5174   [{"iso_3166_1": "US", "name": "United States o...   2007-08-08
# 1735   [{"iso_3166_1": "DE", "name": "Germany"}, {"is...   2008-07-01
# 79698  [{"iso_3166_1": "AU", "name": "Australia"}, {"...   2015-02-13
#
#                                         spoken_languages  movie_id  \
# id
# 64682           [{"iso_639_1": "en", "name": "English"}]     64682
# 9543            [{"iso_639_1": "en", "name": "English"}]      9543
# 5174   [{"iso_639_1": "la", "name": "Latin"}, {"iso_6...      5174
# 1735   [{"iso_639_1": "en", "name": "English"}, {"iso...      1735
# 79698           [{"iso_639_1": "en", "name": "English"}]     79698
#
#                                                     cast  \
# id
# 64682  [{"cast_id": 2, "character": "Jay Gatsby", "cr...
# 9543   [{"cast_id": 5, "character": "Prince Dastan", ...
# 5174   [{"cast_id": 2, "character": "Det. James Carte...
# 1735   [{"cast_id": 1, "character": "Richard O'Connel...
# 79698  [{"cast_id": 11, "character": "James Stewart /...
#
#                                                     crew
# id
# 64682  [{"credit_id": "52fe46e3c3a368484e0a982d", "de...
# 9543   [{"credit_id": "567e74d4c3a36860e9008e46", "de...
# 5174   [{"credit_id": "52fe43fac3a36847f807b5bd", "de...
# 1735   [{"credit_id": "52fe4312c3a36847f80384c5", "de...
# 79698  [{"credit_id": "52fe49e0c3a368484e145067", "de...

# %%
movie_neat_filter = movie_details_join.drop(columns=["original_title", "original_language", "popularity"], axis=1)

# %%
# meaning out 0 budgets - there are a lot, so this is better than removing the rows
movie_neat_filter['budget']=movie_neat_filter['budget'].replace(0,movie_neat_filter['budget'].median())

# %% [markdown]
# The variables used for model prediction were:
# User vote (akin to IMDb rating, referred to as ‘rating’ throughout)
# User-reported box office revenue (referred to as ‘revenue’ throughout)

# %%
# Removing zero REVENUES from the data - revenue is super important as this will 
# be one of the variables we want to predict

def remove_zero_revenue(y_revenue, y_rating, X):
    y_revenue_removed = []
    y_rating_removed = []
    X_removed = []

    for l in range(0,len(y_revenue)):
        if y_revenue[l] !=0:
            y_revenue_removed.append(y_revenue[l])
            y_rating_removed.append(y_rating[l])
            X_removed.append(X[l])        
    y_revenue = np.array(y_revenue_removed)
    y_rating = np.array(y_rating_removed)
    X = np.array(X_removed)
    return y_revenue, y_rating, X

# %%
X = movie_neat_filter.iloc[:, :].values
y_revenue = movie_neat_filter.iloc[:, 2].values
y_rating = movie_neat_filter.iloc[:, 4].values

# %%
#storing removed rows in numpy arrays
y_revenue_nonull, y_rating_nonull, X_nonull = remove_zero_revenue(y_revenue, y_rating, X)

# %%
movie_filter_rev = movie_neat_filter[movie_neat_filter.revenue != 0]

# %% [markdown]
# We want to remove the year from our data as we will not be addressing revenue prediction using time series analysis, and just take into account the seasonality of the release.

# %%
# converting film date to day of year
# i am arguably losing the 'year' which might be slightly correlated with film success
# but that opens up a whole new can of worms about ratings and revenues by year
def remove_year(df):
    datetime_object = list(map(lambda x: datetime.strptime(x,'%Y-%m-%d'), df['release_date']))
    datetime_tuple_ls = []
    for l in datetime_object:
        datetime_tuple = l.timetuple().tm_yday
        datetime_tuple_ls.append(datetime_tuple)
    df['release_date'] = datetime_tuple_ls
    return df

# %%
movie_no_year = remove_year(movie_filter_rev)
# Out:
# /Users/admin/.local/share/virtualenvs/datatonic-challenge-ErycU493/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
#Inspecting processed dataframe
movie_no_year
# Out:
#          budget      id    revenue  runtime  vote_average  vote_count  \
# 0     105000000   64682  351040419    143.0           7.3        3769
# 1     150000000    9543  335154643    116.0           6.2        2317
# 2     140000000    5174  258022233     91.0           6.1         783
# 3     145000000    1735  401128639    112.0           5.2        1387
# 5      15000000  315011   77000000    120.0           6.5         143
# ...         ...     ...        ...      ...           ...         ...
# 4302   14000000   33693      76901     85.0           6.3           8
# 4313      12000     692    6000000     93.0           6.2         110
# 4316      20000   36095      99000    111.0           7.4          63
# 4319       7000   14337     424760     77.0           6.9         658
# 4321     220000    9367    2040920     81.0           6.6         238
#
#                                                  genres  \
# 0     [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 3     [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 5     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...                                                 ...
# 4302  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 4313  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 4316  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4319  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4321  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                                keywords  \
# 0     [{"id": 818, "name": "based on novel"}, {"id":...
# 1     [{"id": 1241, "name": "persia"}, {"id": 1965, ...
# 2                  [{"id": 1704, "name": "ambassador"}]
# 3                                                    []
# 5     [{"id": 1299, "name": "monster"}, {"id": 7671,...
# ...                                                 ...
# 4302             [{"id": 171993, "name": "mumblecore"}]
# 4313  [{"id": 237, "name": "gay"}, {"id": 900, "name...
# 4316  [{"id": 233, "name": "japan"}, {"id": 549, "na...
# 4319  [{"id": 1448, "name": "distrust"}, {"id": 2101...
# 4321  [{"id": 5616, "name": "united states\u2013mexi...
#
#                                                overview  \
# 0     An adaptation of F. Scott Fitzgerald's Long Is...
# 1     A rogue prince reluctantly joins forces with a...
# 2     After an attempted assassination on Ambassador...
# 3     Archaeologist Rick O'Connell travels to China,...
# 5     From the mind behind Evangelion comes a hit la...
# ...                                                 ...
# 4302  Unsure of what to do next, 23-year-old Marnie ...
# 4313  Notorious Baltimore criminal and underground f...
# 4316  A wave of gruesome murders is sweeping Tokyo. ...
# 4319  Friends/fledgling entrepreneurs invent a devic...
# 4321  El Mariachi just wants to play his guitar and ...
#
#                                    production_companies  \
# 0     [{"name": "Village Roadshow Pictures", "id": 7...
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2               [{"name": "New Line Cinema", "id": 12}]
# 3     [{"name": "Universal Pictures", "id": 33}, {"n...
# 5     [{"name": "Cine Bazar", "id": 5896}, {"name": ...
# ...                                                 ...
# 4302                                                 []
# 4313     [{"name": "Dreamland Productions", "id": 407}]
# 4316             [{"name": "Daiei Studios", "id": 881}]
# 4319                 [{"name": "Thinkfilm", "id": 446}]
# 4321           [{"name": "Columbia Pictures", "id": 5}]
#
#                                    production_countries  release_date  \
# 0     [{"iso_3166_1": "US", "name": "United States o...           130
# 1     [{"iso_3166_1": "US", "name": "United States o...           139
# 2     [{"iso_3166_1": "US", "name": "United States o...           220
# 3     [{"iso_3166_1": "DE", "name": "Germany"}, {"is...           183
# 5               [{"iso_3166_1": "JP", "name": "Japan"}]           211
# ...                                                 ...           ...
# 4302  [{"iso_3166_1": "US", "name": "United States o...           263
# 4313  [{"iso_3166_1": "US", "name": "United States o...            72
# 4316            [{"iso_3166_1": "JP", "name": "Japan"}]           310
# 4319  [{"iso_3166_1": "US", "name": "United States o...           282
# 4321  [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...           248
#
#                                        spoken_languages  movie_id  \
# 0              [{"iso_639_1": "en", "name": "English"}]     64682
# 1              [{"iso_639_1": "en", "name": "English"}]      9543
# 2     [{"iso_639_1": "la", "name": "Latin"}, {"iso_6...      5174
# 3     [{"iso_639_1": "en", "name": "English"}, {"iso...      1735
# 5     [{"iso_639_1": "it", "name": "Italiano"}, {"is...    315011
# ...                                                 ...       ...
# 4302           [{"iso_639_1": "en", "name": "English"}]     33693
# 4313           [{"iso_639_1": "en", "name": "English"}]       692
# 4316  [{"iso_639_1": "ja", "name": "\u65e5\u672c\u8a...     36095
# 4319           [{"iso_639_1": "en", "name": "English"}]     14337
# 4321      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]      9367
#
#                                                    cast  \
# 0     [{"cast_id": 2, "character": "Jay Gatsby", "cr...
# 1     [{"cast_id": 5, "character": "Prince Dastan", ...
# 2     [{"cast_id": 2, "character": "Det. James Carte...
# 3     [{"cast_id": 1, "character": "Richard O'Connel...
# 5     [{"cast_id": 4, "character": "Rando Yaguchi : ...
# ...                                                 ...
# 4302  [{"cast_id": 1, "character": "Marnie", "credit...
# 4313  [{"cast_id": 8, "character": "Divine / Babs Jo...
# 4316  [{"cast_id": 3, "character": "Kenichi Takabe",...
# 4319  [{"cast_id": 1, "character": "Aaron", "credit_...
# 4321  [{"cast_id": 1, "character": "El Mariachi", "c...
#
#                                                    crew
# 0     [{"credit_id": "52fe46e3c3a368484e0a982d", "de...
# 1     [{"credit_id": "567e74d4c3a36860e9008e46", "de...
# 2     [{"credit_id": "52fe43fac3a36847f807b5bd", "de...
# 3     [{"credit_id": "52fe4312c3a36847f80384c5", "de...
# 5     [{"credit_id": "5921d321c3a368799b05933f", "de...
# ...                                                 ...
# 4302  [{"credit_id": "52fe45309251416c9102a535", "de...
# 4313  [{"credit_id": "52fe426bc3a36847f801d203", "de...
# 4316  [{"credit_id": "52fe45cc9251416c9103eb7b", "de...
# 4319  [{"credit_id": "52fe45e79251416c75066791", "de...
# 4321  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
#
# [3074 rows x 16 columns]

# %% [markdown]
# ### Making ID maps with the new Dataframe

# %%
movie_copy = movie_no_year.copy() #copy the dataframe so that the original isn't altered
cols_to_dict = ['genres', 'keywords', 'production_companies', 'production_countries',
            'spoken_languages', 'cast', 'crew'] #list of columns that need to be converted from string to dictionary 

movie_dict = convert_to_dict(movie_copy, cols_to_dict, save=True, save_dir = data_dir + 'pre-processed/')
movie_dict.head()
# Out:
# /Users/admin/Documents/Jobs/Datatonic/datatonic-challenge/utils/util.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column][i] = list_to_dict(list_of_dict)  # Convert list of dictionaries to one dictionary
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-b574ab8b7186> in <module>
#       3             'spoken_languages', 'cast', 'crew'] #list of columns that need to be converted from string to dictionary
#       4
# ----> 5 movie_dict = convert_to_dict(movie_copy, cols_to_dict, save=True, save_dir = data_dir + 'pre-processed/')
#       6 movie_dict.head()
#
# ~/Documents/Jobs/Datatonic/datatonic-challenge/utils/util.py in convert_to_dict(df, subset, save, save_dir)
#      72                 for column in subset:                                   # Iterate through columns that need to be converted to dict
#      73                                 for i in range(len(df)):                        # Iterating through every movie
# ---> 74                                         str_entry = data[column][i]                 # Get contents of entry as string
#      75                                         list_of_dict = json.loads(str_entry)        # Convert string into a list of dictionaries
#      76                                         df[column][i] = list_to_dict(list_of_dict)  # Convert list of dictionaries to one dictionary
#
# ~/.local/share/virtualenvs/datatonic-challenge-ErycU493/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/.local/share/virtualenvs/datatonic-challenge-ErycU493/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4402         k = self._convert_scalar_indexer(k, kind="getitem")
#    4403         try:
# -> 4404             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4405         except KeyError as e1:
#    4406             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 4

# %% [markdown]
# Making the id_maps

# %%
id_maps = make_id_maps(data_copy, cols_to_dict[:-2], True, data_dir + 'pre-processed/') #skipping cast and crew as it's more complicated (there are more than 2 keys)

# %% [markdown]
# We want to select independent variables for training during machine learning modelling. I ignored some non-useful variables, such as film title and homepage. Obviously these can’t be used to predict the success of a movie.
#
# Some variables were discarded for other reasons: production_country, because I felt that the information therein would be stored in production_company. Original_language, because I felt that that column would mostly be covered by spoken_languages, with a few exceptions. Popularity, because obviously that was measured after the film was released.
