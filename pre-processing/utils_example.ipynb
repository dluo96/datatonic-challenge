# %% [markdown]
# This notebook is an example on how to import the function in utils (`retrieve_categories` in particular)

# %%
import os

os.chdir('..')
cwd = os.getcwd()

# %%
import pandas as pd
import json

data_dir = '/data/'

# %%
movie_details_neat = pd.read_pickle(cwd + data_dir + 'pre-processed/movie_details_neat.pkl')

movie_details_neat.head()
# Out:
#       budget     id  popularity    revenue  runtime  vote_average  vote_count  \
# 0  105000000  64682   61.196071  351040419    143.0           7.3        3769
# 1  150000000   9543   62.169881  335154643    116.0           6.2        2317
# 2  140000000   5174   22.571780  258022233     91.0           6.1         783
# 3  145000000   1735   60.034162  401128639    112.0           5.2        1387
# 4   27000000  79698    2.418535          0    109.0           4.8          34
#
#                                               genres  \
# 0  {'id': [18, 10749], 'name': ['Drama', 'Romance']}
# 1  {'id': [12, 14, 28, 10749], 'name': ['Adventur...
# 2  {'id': [28, 35, 80, 53], 'name': ['Action', 'C...
# 3  {'id': [12, 28, 14], 'name': ['Adventure', 'Ac...
# 4  {'id': [28, 12, 878, 10749], 'name': ['Action'...
#
#                                             keywords original_language  \
# 0  {'id': [818, 1326, 1523, 3929, 209714], 'name'...                en
# ...

# %%
with open(cwd + data_dir + 'pre-processed/id_maps.json', 'r') as f:
    id_maps = json.load(f)

# %% [markdown]
# Example on how to import the function

# %%
import sys
sys.path.insert(0, os.path.abspath(cwd + '/utils/'))

from util import retrieve_category

# %%
drama_row = retrieve_category(movie_details_neat, column_name='genres', ids=18, id_key_name='id', id_maps=id_maps)

drama_row.head()
# Out:
#       budget      id  popularity    revenue  runtime  vote_average  \
# 0  105000000   64682   61.196071  351040419    143.0           7.3
# 1   15000000  315011    9.476999   77000000    120.0           6.5
# 2  150000000    4922   60.269279  333932083    166.0           7.3
# 3  150000000   27022   35.580815  215283742    109.0           5.8
# 4  150000000    7978   21.214571          0    102.0           5.5
#
#    vote_count                                             genres  \
# 0        3769  {'id': [18, 10749], 'name': ['Drama', 'Romance']}
# 1         143  {'id': [28, 12, 18, 27, 878], 'name': ['Action...
# 2        3292  {'id': [14, 18, 53, 9648, 10749], 'name': ['Fa...
# 3        1470  {'id': [14, 12, 28, 35, 18], 'name': ['Fantasy...
# 4         549  {'id': [18, 27, 53], 'name': ['Drama', 'Horror...
#
#                                             keywords original_language  \
# 0  {'id': [818, 1326, 1523, 3929, 209714], 'name'...                en
# ...
