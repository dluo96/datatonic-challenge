# %% [markdown]
# # Production companies and production countries
#
# This notebook is used to aggregate performances of different production companies and production countries.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../utils/')) #point this to the where util is relatively to your working directory
from util import *

data_dir = get_path_to_data_dir()

# %% [markdown]
# Getting the cleaned dataset

# %%
movie_details_neat = pd.read_pickle(data_dir + 'pre-processed/movie_details_neat.pkl')

movie_details_neat.head()
# Out:
#       budget     id  popularity    revenue  runtime  vote_average  vote_count  \
# 0  105000000  64682   61.196071  351040419    143.0           7.3        3769
# 1  150000000   9543   62.169881  335154643    116.0           6.2        2317
# 2  140000000   5174   22.571780  258022233     91.0           6.1         783
# 3  145000000   1735   60.034162  401128639    112.0           5.2        1387
# 4   27000000  79698    2.418535          0    109.0           4.8          34
#
#                                               genres  \
# 0  {'id': [18, 10749], 'name': ['Drama', 'Romance']}
# 1  {'id': [12, 14, 28, 10749], 'name': ['Adventur...
# 2  {'id': [28, 35, 80, 53], 'name': ['Action', 'C...
# 3  {'id': [12, 28, 14], 'name': ['Adventure', 'Ac...
# 4  {'id': [28, 12, 878, 10749], 'name': ['Action'...
#
#                                             keywords original_language  \
# 0  {'id': [818, 1326, 1523, 3929, 209714], 'name'...                en
# 1  {'id': [1241, 1965, 12653, 12654, 12655, 41645...                en
# 2             {'id': [1704], 'name': ['ambassador']}                en
# 3                                                 {}                en
# 4                                                 {}                en
#
#                           original_title  \
# 0                       The Great Gatsby
# 1    Prince of Persia: The Sands of Time
# 2                            Rush Hour 3
# 3  The Mummy: Tomb of the Dragon Emperor
# 4                             The Lovers
#
#                                             overview  \
# 0  An adaptation of F. Scott Fitzgerald's Long Is...
# 1  A rogue prince reluctantly joins forces with a...
# 2  After an attempted assassination on Ambassador...
# 3  Archaeologist Rick O'Connell travels to China,...
# 4  The Lovers is an epic romance time travel adve...
#
#                                 production_companies  \
# 0  {'name': ['Village Roadshow Pictures', 'Bazmar...
# 1  {'name': ['Walt Disney Pictures', 'Jerry Bruck...
# 2          {'name': ['New Line Cinema'], 'id': [12]}
# 3  {'name': ['Universal Pictures', 'China Film Co...
# 4  {'name': ['Corsan', 'Bliss Media', 'Limelight ...
#
#                                 production_countries release_date  \
# 0  {'iso_3166_1': ['US', 'AU'], 'name': ['United ...   2013-05-10
# 1  {'iso_3166_1': ['US'], 'name': ['United States...   2010-05-19
# 2  {'iso_3166_1': ['US'], 'name': ['United States...   2007-08-08
# 3  {'iso_3166_1': ['DE', 'US'], 'name': ['Germany...   2008-07-01
# 4  {'iso_3166_1': ['AU', 'BE', 'IN'], 'name': ['A...   2015-02-13
#
#                                     spoken_languages  movie_id  \
# 0         {'iso_639_1': ['en'], 'name': ['English']}     64682
# 1         {'iso_639_1': ['en'], 'name': ['English']}      9543
# 2  {'iso_639_1': ['la', 'en', 'fr', 'ja', 'zh'], ...      5174
# 3  {'iso_639_1': ['en', 'zh', 'sa'], 'name': ['En...      1735
# 4         {'iso_639_1': ['en'], 'name': ['English']}     79698
#
#                                                 cast  \
# 0  {'cast_id': [2, 5, 3, 8, 6, 4, 7, 22, 13, 23, ...
# 1  {'cast_id': [5, 2, 7, 4, 6, 8, 9, 10, 26, 27, ...
# 2  {'cast_id': [2, 3, 4, 5, 6, 7, 8, 9, 26, 27, 2...
# 3  {'cast_id': [1, 2, 8, 12, 13, 14, 15, 16, 17, ...
# 4  {'cast_id': [11, 13, 22, 17, 14, 15, 16, 18, 1...
#
#                                                 crew
# 0  {'credit_id': ['52fe46e3c3a368484e0a982d', '52...
# 1  {'credit_id': ['567e74d4c3a36860e9008e46', '52...
# 2  {'credit_id': ['52fe43fac3a36847f807b5bd', '52...
# 3  {'credit_id': ['52fe4312c3a36847f80384c5', '52...
# 4  {'credit_id': ['52fe49e0c3a368484e145067', '57...

# %%
with open(data_dir + 'pre-processed/id_maps.json', 'r') as f:
    id_maps = json.load(f)

# %%
def check_category(id_maps, column_name):
    print(json.dumps(id_maps[column_name], indent=4))

# %%
check_category(id_maps, 'production_countries')
# Out:
# {
#     "US": "United States of America",
#     "AU": "Australia",
#     "DE": "Germany",
#     "BE": "Belgium",
#     "IN": "India",
#     "JP": "Japan",
#     "GB": "United Kingdom",
#     "CA": "Canada",
#     "IT": "Italy",
#     "ES": "Spain",
#     "CN": "China",
#     "NZ": "New Zealand",
#     "FR": "France",
#     "HK": "Hong Kong",
#     "IE": "Ireland",
#     "MA": "Morocco",
#     "HU": "Hungary",
#     "SG": "Singapore",
#     "NO": "Norway",
#     "SE": "Sweden",
#     "ZA": "South Africa",
#     "RU": "Russia",
#     "RO": "Romania",
#     "MX": "Mexico",
#     "CZ": "Czech Republic",
#     "MC": "Monaco",
#     "CH": "Switzerland",
#     "PK": "Pakistan",
#     "MY": "Malaysia",
#     "FI": "Finland",
#     "IS": "Iceland",
#     "DK": "Denmark",
#     "TN": "Tunisia",
#     "PH": "Philippines",
#     "AE": "United Arab Emirates",
#     "BG": "Bulgaria",
#     "MT": "Malta",
#     "KR": "South Korea",
#     "BR": "Brazil",
#     "PE": "Peru",
#     "NL": "Netherlands",
#     "LU": "Luxembourg",
#     "BA": "Bosnia and Herzegovina",
#     "KZ": "Kazakhstan",
#     "PT": "Portugal",
#     "PL": "Poland",
#     "AW": "Aruba",
#     "LY": "Libyan Arab Jamahiriya",
#     "RS": "Serbia",
#     "UA": "Ukraine",
#     "CL": "Chile",
#     "AR": "Argentina",
#     "PA": "Panama",
#     "AT": "Austria",
#     "GR": "Greece",
#     "TW": "Taiwan",
#     "LT": "Lithuania",
#     "TH": "Thailand",
#     "SK": "Slovakia",
#     "IL": "Israel",
#     "FJ": "Fiji",
#     "CS": "Serbia and Montenegro",
#     "BS": "Bahamas",
#     "TR": "Turkey",
#     "NG": "Nigeria",
#     "CY": "Cyprus",
#     "JO": "Jordan",
#     "BO": "Bolivia",
#     "EC": "Ecuador",
#     "CO": "Colombia",
#     "EG": "Egypt",
#     "BT": "Bhutan",
#     "LB": "Lebanon",
#     "ID": "Indonesia",
#     "JM": "Jamaica",
#     "GY": "Guyana",
#     "IR": "Iran",
#     "AF": "Afghanistan",
#     "AO": "Angola",
#     "CM": "Cameroon"
# }

# %% [markdown]
# The following function generates the average values on the categories in the columns.

# %%
from tqdm import tqdm
import numpy as np

def get_averages_for_columns(df, id_maps, id_key_name, column_name, save=False, save_dir=''):
    appearances = []
    cols_with_num_vals = ['budget', 'popularity', 'revenue', 'runtime', 'vote_average', 'vote_count']
    prod_comp_avgs = {}
    for col in cols_with_num_vals:
        prod_comp_avgs[col] = []

    for ids in tqdm(id_maps[column_name].keys()):
        # Retrieve rows for a certain production companies
        print(ids)
        if ids.isdigit():
            ids = int(ids)
        row = retrieve_category(df=df, column_name=column_name, ids=ids, id_key_name=id_key_name, id_maps=id_maps, save=False)
        # Aggregate the data and append it to the lists
        print(row)
        agg_data = row[cols_with_num_vals].agg(['mean'])
        count = row.shape[0]
        for col in cols_with_num_vals:
            prod_comp_avgs[col].append(agg_data[col]['mean'])
        appearances.append(count)

    data = {'id': list(id_maps[column_name].values())}

    for col in cols_with_num_vals:
        data[col] = prod_comp_avgs[col]
    data['appearances'] = appearances

    result = pd.DataFrame.from_dict(data)
    if save:
        result.to_pickle(save_dir + 'movie_' + column_name +'_summary.pkl')
    
    return result

# %%
prod_companies = get_averages_for_columns(movie_details_neat, id_maps, 'id', 'production_companies', True, data_dir+'pre-processed/')
# Out:
# 100%|██████████| 4741/4741 [06:09<00:00, 12.82it/s]

# %%
prod_companies.head()
# Out:
#                           id        budget  popularity       revenue  \
# 0  Village Roadshow Pictures  6.050704e+07   28.754815  1.303950e+08
# 1              Bazmark Films  7.550000e+07   47.226113  1.817767e+08
# 2               Warner Bros.  4.518166e+07   25.835690  1.030195e+08
# 3    A&E Television Networks  1.050000e+08   61.196071  3.510404e+08
# 4    Red Wagon Entertainment  8.740000e+07   58.792163  1.844831e+08
#
#       runtime  vote_average   vote_count  appearances
# 0  108.126761      5.914085   969.943662           71
# 1  138.750000      6.925000  1784.250000            4
# 2  113.666667      6.252381   819.864469          273
# 3  143.000000      7.300000  3769.000000            1
# 4  127.000000      6.720000  2216.400000            5

# %% [markdown]
# The following function generates the average values on the columns for different production countries.

# %%
prod_countries = get_averages_for_columns(movie_details_neat, id_maps, 'iso_3166_1', 'production_countries', True, data_dir+'pre-processed/')
# Out:
#   0%|          | 0/80 [00:00<?, ?it/s]
# US
# Empty DataFrame
# Columns: []
# Index: []
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-53d955404336> in <module>
# ----> 1 prod_countries = get_averages_for_columns(movie_details_neat, id_maps, 'iso_639_1', 'production_countries', True, data_dir+'pre-processed/')
#
# <ipython-input-6-c68d833d505d> in get_averages_for_columns(df, id_maps, id_key_name, column_name, save, save_dir)
#      17         # Aggregate the data and append it to the lists
#      18         print(row)
# ---> 19         agg_data = row[cols_with_num_vals].agg(['mean'])
#      20         count = row.shape[0]
#      21         for col in cols_with_num_vals:
#
# ~/.local/share/virtualenvs/datatonic-challenge-vXlODfEJ/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~/.local/share/virtualenvs/datatonic-challenge-vXlODfEJ/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~/.local/share/virtualenvs/datatonic-challenge-vXlODfEJ/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['budget', 'popularity', 'revenue', 'runtime', 'vote_average',\n       'vote_count'],\n      dtype='object')] are in the [columns]"

# %%
prod_companies.describe()
# Out:
#              budget   popularity       revenue      runtime         vote  \
# count  4.741000e+03  4741.000000  4.741000e+03  4741.000000  4741.000000
# mean   2.250971e+07    18.478442  4.843291e+07   107.080984     6.224094
# std    2.676551e+07    16.437388  7.236547e+07    15.947909     0.868265
# min    0.000000e+00     0.008453  0.000000e+00    41.000000     2.700000
# 25%    2.080000e+06     6.169125  7.920000e+02    96.000000     5.750000
# 50%    1.300000e+07    14.033065  1.774253e+07   105.000000     6.300000
# 75%    3.300000e+07    26.023778  6.836849e+07   116.000000     6.800000
# max    1.500000e+08   116.700319  5.463881e+08   174.000000     9.300000
#
#         vote_count  appearances
# count  4741.000000  4741.000000
# mean    501.616981     2.632567
# std     630.795972     9.866856
# min       1.000000     1.000000
# 25%      77.000000     1.000000
# 50%     273.666667     1.000000
# 75%     672.500000     2.000000
# max    4369.000000   281.000000

# %%
# Select all with appearances > 2
prod_companies_pop = prod_companies[prod_companies['appearances'] > 10]

prod_companies_pop.head()
prod_companies_pop.shape
# Out:
#                           id        budget  popularity       revenue  \
# 0  Village Roadshow Pictures  6.050704e+07   28.754815  1.303950e+08
# 1              Bazmark Films  7.550000e+07   47.226113  1.817767e+08
# 2               Warner Bros.  4.518166e+07   25.835690  1.030195e+08
# 4    Red Wagon Entertainment  8.740000e+07   58.792163  1.844831e+08
# 6       Walt Disney Pictures  5.139402e+07   25.185501  1.228373e+08
#
#       runtime      vote   vote_count  appearances
# 0  108.126761  5.914085   969.943662           71
# 1  138.750000  6.925000  1784.250000            4
# 2  113.666667  6.252381   819.864469          273
# 4  127.000000  6.720000  2216.400000            5
# 6   98.885057  6.133333   666.747126           87

# %%
prod_companies_pop.describe()
# Out:
#              budget  popularity       revenue     runtime        vote  \
# count  7.760000e+02  776.000000  7.760000e+02  776.000000  776.000000
# mean   3.237169e+07   23.776206  7.584368e+07  108.818227    6.256350
# std    2.308496e+07   12.128248  6.694809e+07   10.981090    0.501858
# min    0.000000e+00    1.269261  0.000000e+00   75.250000    4.066667
# 25%    1.366667e+07   14.724189  2.452074e+07  101.666667    5.933333
# 50%    2.892708e+07   22.115698  5.767131e+07  107.845238    6.292857
# 75%    4.674167e+07   30.953768  1.066057e+08  114.616667    6.575000
# max    1.100000e+08   81.189652  4.408696e+08  151.333333    7.966667
#
#         vote_count  appearances
# count   776.000000   776.000000
# mean    710.805548    10.184278
# std     516.125171    22.945339
# min      14.333333     3.000000
# 25%     318.000000     3.000000
# 50%     611.100000     5.000000
# 75%     960.300000     8.000000
# max    3350.666667   281.000000

# %% [markdown]
# Highest budget

# %%
prod_companies_pop.nlargest(5,['budget'])
# Out:
#                                 id        budget  popularity       revenue  \
# 379        Pixar Animation Studios  1.100000e+08   81.189652  4.408696e+08
# 53   Walt Disney Animation Studios  1.087500e+08   33.957943  1.576196e+08
# 157  Walt Disney Feature Animation  1.078125e+08   48.380295  2.412265e+08
# 40    Moving Picture Company (MPC)  1.071250e+08   58.897455  1.840042e+08
# 108                      TIK Films  1.066667e+08   53.468325  2.108397e+08
#
#         runtime    vote   vote_count  appearances
# 379  101.333333  6.9000  3328.666667            3
# 53    86.500000  6.3250   863.500000            4
# 157   85.625000  6.7875  1240.875000            8
# 40   104.625000  5.7125  1513.875000            8
# 108  120.666667  5.9000  1942.666667            3

# %% [markdown]
# Highest revenue

# %%
prod_companies_pop.nlargest(5,['revenue'])
# Out:
#                                id        budget  popularity       revenue  \
# 379       Pixar Animation Studios  1.100000e+08   81.189652  4.408696e+08
# 160              Blue Sky Studios  8.766667e+07   48.123314  3.572397e+08
# 247  Kerner Entertainment Company  1.000000e+08   27.753477  3.517278e+08
# 64      Pacific Data Images (PDI)  9.214286e+07   44.059230  3.514324e+08
# 394       Bagdasarian Productions  4.500000e+07   34.871888  3.460874e+08
#
#         runtime      vote   vote_count  appearances
# 379  101.333333  6.900000  3328.666667            3
# 160   93.333333  6.466667  1676.500000            6
# 247  101.666667  5.600000   720.666667            3
# 64    87.857143  6.342857  1887.142857            7
# 394   90.666667  5.566667   757.000000            3

# %% [markdown]
# Most popular

# %%
prod_companies_pop.nlargest(5,['popularity'])
# Out:
#                           id        budget  popularity       revenue  \
# 379  Pixar Animation Studios  1.100000e+08   81.189652  4.408696e+08
# 192              Genre Films  7.920000e+07   78.804012  2.477307e+08
# 681  Fuji Television Network  3.666667e+07   64.512516  1.533051e+08
# 234                  NeoReel  1.016667e+08   62.934680  2.632031e+08
# 85             LStar Capital  5.290000e+07   60.000144  1.309338e+08
#
#         runtime      vote   vote_count  appearances
# 379  101.333333  6.900000  3328.666667            3
# 192  107.600000  6.100000  2474.400000            5
# 681  102.000000  5.666667  1517.666667            3
# 234  110.000000  5.800000  1946.666667            3
# 85   110.200000  6.050000  1843.700000           10

# %% [markdown]
# Longest runtime

# %%
prod_companies_pop.nlargest(5,['runtime'])
# Out:
#                                id        budget  popularity       revenue  \
# 398   Stanley Kubrick Productions  5.850000e+07   49.368870  1.555726e+08
# 826                        Ixtlan  3.800000e+07   26.977809  1.147329e+08
# 1151                   Rai Cinema  2.111325e+07   16.396355  3.383491e+07
# 237                  Forward Pass  8.520000e+07   35.683508  9.616121e+07
# 414        First Light Production  5.166667e+07   33.646355  6.999656e+07
#
#          runtime      vote   vote_count  appearances
# 398   151.333333  7.266667  2068.666667            3
# 826   146.333333  6.566667   527.666667            3
# 1151  145.333333  6.966667   400.000000            3
# 237   142.000000  6.480000   930.600000            5
# 414   142.000000  6.666667  1268.666667            3

# %% [markdown]
# Shortest runtime

# %%
prod_companies_pop.nsmallest(5,['runtime'])
# Out:
#                                     id        budget  popularity  \
# 2167  Walt Disney Television Animation  1.500000e+07   10.558639
# 1407                   Starz Animation  2.233333e+07   21.299913
# 2474                       SNL Studios  1.366667e+07    6.338591
# 650     Joseph M. Singer Entertainment  7.033333e+07   14.599347
# 4038              Silver Nitrate Films  0.000000e+00    4.238618
#
#            revenue    runtime      vote  vote_count  appearances
# 2167  7.250088e+07  75.250000  5.950000  157.000000            4
# 1407  3.740947e+07  81.666667  5.900000  462.000000            3
# 2474  1.467706e+07  82.000000  5.566667  105.000000            3
# 650   1.568536e+08  83.000000  4.700000  381.333333            3
# 4038  0.000000e+00  84.666667  4.066667   52.666667            3

# %% [markdown]
# Highest vote average

# %%
prod_companies_pop.nlargest(5,['vote'])
# Out:
#                                    id        budget  popularity       revenue  \
# 1517                    Studio Ghibli  3.072590e+07   49.956494  1.938551e+08
# 2844  Selznick International Pictures  9.293333e+05   11.198043  4.333333e+06
# 2436                           Filmax  3.150000e+06   16.135224  3.699622e+07
# 1451      Filmförderungsanstalt (FFA)  2.933333e+07   32.805979  8.642831e+07
# 2725                             Arte  8.450000e+06   18.774464  4.752292e+07
#
#          runtime      vote   vote_count  appearances
# 1517  117.666667  7.966667  1633.333333            3
# 2844  114.000000  7.800000   169.000000            3
# 2436   99.750000  7.575000   407.500000            4
# 1451  139.666667  7.466667   984.666667            3
# 2725  134.250000  7.450000   499.750000            4

# %% [markdown]
# Highest vote count

# %%
prod_companies_pop.nlargest(5,['vote_count'])
# Out:
#                             id        budget  popularity       revenue  \
# 44   Bad Hat Harry Productions  8.933333e+07   22.051050  2.860287e+08
# 379    Pixar Animation Studios  1.100000e+08   81.189652  4.408696e+08
# 33        Plan B Entertainment  1.000000e+08   48.711620  3.231367e+08
# 423                   Hypnotic  7.333333e+07   53.636249  2.415885e+08
# 202       Marvel Entertainment  9.900000e+07   34.233939  2.442119e+08
#
#         runtime      vote   vote_count  appearances
# 44   116.166667  6.816667  3350.666667            6
# 379  101.333333  6.900000  3328.666667            3
# 33   133.000000  6.800000  2866.333333            3
# 423  105.000000  6.800000  2735.666667            3
# 202  107.000000  5.133333  2488.666667            3

# %% [markdown]
# Appeared most in data

# %%
prod_companies_pop.nlargest(5,['appearances'])
# Out:
#                                         id        budget  popularity  \
# 9                       Universal Pictures  3.901198e+07   25.515336
# 2                             Warner Bros.  4.518166e+07   25.835690
# 26                      Paramount Pictures  3.763521e+07   22.140408
# 35  Twentieth Century Fox Film Corporation  4.248594e+07   26.318939
# 49                       Columbia Pictures  4.559268e+07   26.943474
#
#          revenue     runtime      vote  vote_count  appearances
# 9   1.034093e+08  111.256228  6.227758  792.967972          281
# 2   1.030195e+08  113.666667  6.252381  819.864469          273
# 26  9.635208e+07  108.339844  6.161719  627.570312          256
# 35  1.252882e+08  106.939698  6.108040  887.356784          199
# 49  1.013324e+08  108.883978  6.146409  830.132597          181

# %%
import seaborn as sns

sns.distplot(prod_companies_pop['budget'], kde=False)

# %%
sns.distplot(prod_companies_pop['runtime'], kde=False)

# %% [markdown]
# TODO: Comparison of different genres for production houses
